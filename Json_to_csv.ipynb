# %% [markdown]
# ##JSON to CSV

# %%
from google.colab import files
uploaded  = files.upload()

# %%
import json
import csv
 
 
# Opening JSON file and loading the data
# into the variable data
with open('task2_headnotes.json') as json_file:
    data = json.load(json_file)
    k = data.keys()
 
data_file = open('headnotes_data_file.csv', 'a+')

for i in k:
  employee_data = data[i]
  csv_writer = csv.writer(data_file)
  count = 0
  for emp in employee_data:
    if count == 0:
      header = emp.keys()
      csv_writer.writerow(header)
      count += 1
    csv_writer.writerow(emp.values())

# %%
import pandas as pd
pd.set_option("display.max_colwidth", -1)
hn_df = pd.read_csv("headnotes_data_file.csv")
jd_df = pd.read_csv("judgements_data_file.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
hn_df.head(20)
# Out:
#     id                                                                                                                                                                                                                                                                                                                                                                                                              sentence
# 0   1   The appellant appointed the 1st respondent as a Welfare Officer as required by the Factories Act, 1948 and the Punjab Welfare Officers Recruitment and Conditions of Service Rules, 1952.
# 1   2   The letter of appointment stated that the 1st respondent was liable to be transferred from one unit of the appellant to another and that his services could be terminated by the appellant by one month's notice or with one month's pay in lieu ;thereof.
# 2   3   On the 1st respondent being unprepared to go to a place to which he was transferred, tile appellant terminated his services with one month's salary.
# 3   4   The 1st respondent appealed to the 2nd respondent, the State of Punjab, the appellate authority under rule 6(6) and the 2nd respondent ordered his reinstatement as the previous concurrence of the Labour Commissioner as required by rule 6(3), proviso 2, was not obtained.
# 4   5   In appeal to the Supreme Court it was contended that : (i) the rule requiring the concurrence of the Labour Commissioner was invalid as it was outside the scope of the rule-making authority conferred on the State Government by section 49(2) of the Act, and (ii) the order of reinstatement passed by the 2nd respondent was invalid as the appeal by the 1st respondent to the 2nd respondent was incompetent.
# 5   6   The 1st respondent also raised a preliminary objection that the appeal to the Supreme Court was incompetent because the 2nd respondent was not a tribunal within the meaning of article  136(1) of the Constitution.
# 6   7   HELD : (i) The 2nd respondent is a tribunal within the meaning of article 136(1) having regard to the distinctive features of the power concerted on it by rule 6(5) and (6). [387 B] (Per Gajendragadkar, C.  J. , M.  Hidayatullah, J.  C.  Shah and S.  M.  Sikri, JJ. )
# 7   8   : In considering the question about the status of any body or authority as a tribunal under the article, the consideration about the presence of all or some of the trappings of a court is really not decisive.
# 8   9   The presence of some of the trappings may assist the determination of the question as to whether the power exercised by the authority which possessed the said trappings, is the judicial power of the State or not.
# 9   10  The main and basic test however, is whether the adjudicating power which a particular authority is empowered to exercise, has been conferred on it by a statute -and can be described as a part of the State's inherent power exercised in discharging its judicial function.
# 10  11  Applying the test, there can be no doubt that the power which the 2nd respondent exercised under rr. 6(5) and (6) of the Rules is a part of the State's judicial power.
# 11  12  It has been conferred on the 2nd respondent by a statutory rule and it can be exercised in respect of disputes between the management and its welfare officers.
# 12  13  There is a lis an affirmation by one party and denial by another, 367 and the dispute necessarily involves the rights and obligations of the par-ties to it.
# 13  14  The order which the 2nd respondent ultimately passes is described as its decision and it is made final and binding.
# 14  15  Besides, it is an order passed on appeal.
# 15  16  In reaching a fair and objective decision in the dispute brought before it in its appellate jurisdiction, the State Government has the power to devise its own procedure and to exercise such other incidental and subsidiary powers as may be necessary to deal effectively with the dispute.
# 16  17  [386 F-H; 387 A-B, E] Per Bachawat, J.
# 17  18  The basic test of a tribunal within the meaning of article 136, is that it is an adjudicating authority (other than a court) vested with the judicial power of the State.
# 18  19  In India, the State has inherent judicial powers or functions and the courts and other authorities vested by the State with judicial functions are regarded as delegates of the State judicial power.
# 19  20  The courts alone have no monopoly of the judicial power.

# %%
jd_df.head(20)
# Out:
#     id  ... relevance
# 0   1   ...  0
# 1   2   ...  0
# 2   3   ...  0
# 3   4   ...  1
# 4   5   ...  1
# 5   6   ...  1
# 6   7   ...  0
# 7   8   ...  1
# 8   9   ...  0
# 9   10  ...  0
# 10  11  ...  0
# 11  12  ...  1
# 12  13  ...  1
# 13  14  ...  1
# 14  15  ...  0
# 15  16  ...  0
# 16  17  ...  0
# 17  18  ...  0
# 18  19  ...  0
# 19  20  ...  1
#
# [20 rows x 4 columns]
